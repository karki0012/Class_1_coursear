# %% [markdown]
# # Feature scaling and learning rate
#
# Goals
# - Utilization of multiple variables
# - Run Gradient Descent for data set with multiple fatures
# - explore the impact of learning rate
# - improve the performance of gradient descent

# %% [markdown]
# ## Tools
# Utalize the functions of matplotlib and NumPy

# %%
# Import library 
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading the dataset

# %% [markdown]
# ## Gradient Descent With Multiple Variables
# Here are the equations for multiple variables.:
#
# $$
# \begin{align*}
# \text{repeat until convergence:} \;\lbrace \newline\;
# & w_j := w_j -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial w_j} \tag{1}  \; & \text{for j = 0..n-1}\newline
# &b\ \ := b -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial b}  \newline \rbrace
# \end{align*}
# $$
#
# where, n is the number of features, parameters $w_j$,  $b$, are updated simultaneously and where
#
# $$
# \begin{align}
# \frac{\partial J(\mathbf{w},b)}{\partial w_j}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)})x_{j}^{(i)} \tag{2}  \\
# \frac{\partial J(\mathbf{w},b)}{\partial b}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)}) \tag{3}
# \end{align}
# $$
# * m is the number of training examples in the data set
#
#
# *  $f_{\mathbf{w},b}(\mathbf{x}^{(i)})$ is the model's prediction, while $y^{(i)}$ is the target value

# %% [markdown]
# ## Z-score normalization
# After Z-score normalization, all features will have a mean of $0$ and a standard deviation of 1.
#
# To implement Z-score normalization, adjust your input values as shown in the formula:
#
# $$
# x^{(i)}_j = \frac {x^{(i)}_j - \mu _j}{\sigma _j} \tag{4}
# $$
# where $j$ selects the features or a column in the $\mathbf{X}$ matrix. $\mu _j $ is the mean of all the variables for the feature (j) and $ \sigma _j $ is the standard deviation for feature (j).
# $$
# \begin{align}
# \mu _j &= \frac {1}{m} \sum _{i=0}^{m-1} x^{(i)}_j \tag{5} \\
# \sigma _j ^2 &= \frac {1}{m} \sum _{i=0}^{m-1} (x^{(i)}_j - \mu _j)^2 \tag{6}
# \end{align}
# $$

# %%
def zscore_narmalize_features(X):
    """
    computes X, zscore normalized by column

    Args:
    X (ndarray(m,n)) : input data, m numbers, n features

    Returns:
    X_norm (ndarray (m,n))  : input normalized by column
    mu (ndarray(n,))        : mean of each feature
    sigma (ndarray(n,))     : standard deviation of each features  

    """

    # finding the mean of each column/features
    mu = np.mean(X, axis=0)    # mu will have shape (n,)
    # find the standard deviation of each column/feature
    sigma  = np.std(X, axis=0)                  # sigma will have shape (n,)
    # element-wise, subtract mu for that column from each example, divide by std for that column
    X_norm = (X - mu) / sigma      

    return (X_norm, mu, sigma)
